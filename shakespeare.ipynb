# %%
import tensorflow as tf
from tensorflow.contrib import layers
from tensorflow.contrib import rnn
import os
import time
import math
import numpy as np
import my_txtutils as txt
import sys

tf.set_random_seed(0)
tf.reset_default_graph()

SEQLEN = 30
BATCHSIZE = 20
ALPHABETSIZE = txt.ALPHASIZE # 98 characters in vocab being used
INTERNALSIZE = 128
NLAYERS = 1

keep_prob = 0.8

# %%
# Load Shakespeare Data 

shakedir = "shakespeare/*.txt"

codetext, valitext, bookranges = txt.read_data_files(shakedir, validation=True)

# My_txtuils.py

    # uses glob for pathnames
    # convert_from_alphabet() - convert to ASCII values
# Out:
# Loading file shakespeare/2kinghenryvi.txt
# Loading file shakespeare/asyoulikeit.txt
# Loading file shakespeare/hamlet.txt
# Loading file shakespeare/kingjohn.txt
# Loading file shakespeare/loverscomplaint.txt
# Loading file shakespeare/merchantofvenice.txt
# Loading file shakespeare/othello.txt
# Loading file shakespeare/sonnets.txt
# Loading file shakespeare/titusandronicus.txt
# Loading file shakespeare/various.txt

# %%
# Some statistics

epoch_size = len(codetext) // BATCHSIZE * SEQLEN

txt.print_data_stats(len(codetext), len(valitext), epoch_size)
# Out:
# Training text size is 0.93MB with 139.61KB set aside for validation. There will be 1458420 batches per epoch

# %%
# Placeholders

    # URL: https://learningtensorflow.com/lesson4/
    
"""Placeholder: a variable that we will assign data to at a later date. 
It allows us to create our operations and build our computation
graph, without needing the data. 

In TensorFlow terminology, we then feed data into the graph
through these placeholders."""

# Define placeholders 

keep_prob_placeholder = tf.placeholder(tf.float32, name = 'keep_prob') # dropout param
batchsize = tf.placeholder(tf.int32, name = 'batchsize')

# inputs 

X = tf.placeholder(tf.uint8, [None, None], name = 'X')
Xo = tf.one_hot(X, ALPHABETSIZE, 1.0, 0.0)

# expected outputs = same sequence shifted by 1 since we are trying
# to predict next character

Y_ = tf.placeholder(tf.uint8, [None, None], name = 'Y_')
Yo_ = tf.one_hot(Y_, ALPHABETSIZE, 1.0, 0.0)

# Input state

Hin = tf.placeholder(tf.float32, [None, INTERNALSIZE*NLAYERS], name = 'Hin')

# %%
# using NLAYERS of GRU cells, unrolled SEQLEN=30 times
# dynamic_rnn infers SEQLEN from the size of the inputs Xo

cells = [rnn.GRUCell(INTERNALSIZE) for _ in range(NLAYERS)]

# "naive dropout" implementaiton
dropcells = [rnn.DropoutWrapper(cell, input_keep_prob=keep_prob_placeholder) for cell in cells]

multicell = rnn.MultiRNNCell(dropcells, state_is_tuple=False) 

multicell = rnn.DropoutWrapper(multicell,
                               output_keep_prob = keep_prob_placeholder)
                                #dropout for the softmax layer

Yr, H = tf.nn.dynamic_rnn(multicell, Xo, dtype=tf.float32, initial_state = Hin)

# %%
# Softmax layer implementation
# Flatten the first two dimension of the output
    # [BATCHSIZE, SEQLEN, ALPHABETSIZE] => [ BATCHSIZE*SEQLEN, ALPHASIZE]
# then apply softmax laye.
    # Weights and biases are shared across unrolled time steps
    
W = tf.Variable(tf.random_normal([INTERNALSIZE, ALPHABETSIZE]))
B = tf.Variable(tf.random_normal([ALPHABETSIZE]))

Yflat = tf.reshape(Yr, [-1, INTERNALSIZE]) # [BATCHSIZE*SEQLEN, INTERNALSIZE]
Ylogits = tf.matmul(Yflat, W) + B # [BATCHSIZE*SEQLEN, ALPHASIZE]

Yflat = tf.reshape(Yo_, [-1, ALPHABETSIZE])

loss = tf.nn.softmax_cross_entropy_with_logits(logits = Ylogits, labels = Yflat)
loss = tf.reshape(loss, [batchsize, -1])

Yo = tf.nn.softmax(Ylogits, name = 'Yo')
Y = tf.argmax(Yo, 1)
Y = tf.reshape(Y, [batchsize, -1], name = "Y")

train_step = tf.train.AdamOptimizer(0.001).minimize(loss)

# %%
# Stats for display

seqloss = tf.reduce_mean(loss,1)
batchloss = tf.reduce_mean(seqloss)
accuracy = tf.reduce_mean(tf.cast(tf.equal(Y_, tf.cast(Y, tf.uint8)), tf.float32))

# Proress bar

DISPLAY_FREQ = 50
_50_BATCHES = DISPLAY_FREQ * BATCHSIZE * SEQLEN

progress = txt.Progress(DISPLAY_FREQ, size = 111+2,
                         msg = "Training on next" + str(DISPLAY_FREQ) +"batches")

# %%
# init

istate = np.zeros([BATCHSIZE, INTERNALSIZE * NLAYERS])

init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)
step = 0

# %%
# training loop

for x, y_, epoch in txt.rnn_minibatch_sequencer(codetext, BATCHSIZE,
                                               SEQLEN, nb_epochs =2):
    
    # train on one minibatch
    
    feed_dict = {X: x, Y_: y_, Hin: istate, keep_prob_placeholder: keep_prob, batchsize: BATCHSIZE}

    _, y, ostate = sess.run([train_step, Y, H], feed_dict=feed_dict)
    
    # display a short text generated with current weights and biases
    
    if step // 3 % _50_BATCHES == 0:
        print
        print "Generating some random text..."
        
        ry = np.array([[txt.convert_from_alphabet(ord("K"))]])
        rh = np.zeros([1, INTERNALSIZE*NLAYERS])
        
        for k in range(1000):
            ryo, rh = sess.run([Yo, H], feed_dict = {X: ry,
                                                     keep_prob_placeholder: 1.0,
                                                    Hin: rh, batchsize: 1})
            
            rc = txt.sample_from_probabilities(ryo, topn=10 if epoch <= 1 else 2)
            
            sys.stdout.write(chr(txt.convert_to_alphabet(rc)))
            
            ry = np.array([[rc]])
            
        print
        print "FINISHED GENERATING RANDOM TEXT"
        print
        
    # display progress bar
    progress.step(reset = step % _50_BATCHES == 0)
    
    # loop state around
    istate = ostate
    step += BATCHSIZE * SEQLEN
    
print 
print "----FINISHED TRAINING"
# Out:
# ==============================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# osT oo mirenande higleaver morserstlen, ho titsit hor oourele sheare thy oue wang owaldalinors.
#
# THeer this thesellatr thout our me an tlis wnd hithr ool ther how day howsthangordie ted mars, myorr to th r mesime aysuray.
#
# OAnI mind sheslere, thear old the brathes. hie show, thet woure hive at he tlisoungt aser ase, ingear, aner the dies and sa litr hom on tured
# 	Wous ord aritirit.
#
# AUSSIIA	O	Art som me heallsa and hand some ie seda andiglligin teere tingher womestis, fath wishy sourled if merart, ar tly sot of an ad ane at onaso ros.
# 	Lart at tht bay sallited ain ter chavellomar aderow art, my ar is, hourede hir at ime and ang t he s airle tur teee mon eryourdooull sampe lerd wary or sowhthe deighre or ie. he weratlig dad shathiss ho sthill maslim. hat har te haman,
# 	Hou tla sierth anis lart merashis. hingeds ofored.
#
# 	[nt enrengal, sollit on terrsengl sorentteende tye so he thera bed oo dadirdeas,
# 	oot beran ste s ans mere fise aofl,ir hea therlldad oour soreretower will s de s all b
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================
# 	Is when thane,	Womdon im you foreesho  of muthin, and if a hams, ond,
#
# SALER	Ner, ware mires, and shond te le bardeare the soo ders oo some mo hat or and wns berso oofend wist.
# 	What you ale th s culf suer bear,
# 	Seed ton or here wo thus tlote ay mon,
# 	And mo nour ar orie oote
#
# And as and of thar ier thin yow ofth taknstones of
# 	Wear care astelave you him; be athen
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# No given all betath your
# Thendeshares
# 	Ant so this dienthan thans bon thin
# 	Tha he hucaspant tans brurnt thes
# 	Tit thy laits or herd st wen
# 	Seale tes weat and nove the thun wing and yourgontire,
#
# 	At  ut and well sour and all an, thy bale, that woll as the all to me hear,
# 	And shin, you thellsonter shet thenglat my warte t th nower wee me betirnow
# 	And my tere to thin her me thiver meanto wer amese by ars avert, bratsthene asthe an areatend wire,
# 	I aivid,
# Whty we thetothart to meal tienser he batow
#
#
# The s of the goon berith net hto hord fom then was bedsarasse to tous saishto hin tain, aleady tho mes ou ningstondessowe at andelfor in may
# 	are trieg wish whe mes th  teat mod on greath tht ste st and mish stofto hime hame his and sall he ss belst me, ther tlle, art or with ster siol blt ourenot.
#
#
# ALELLAU		hat you  ore thet hend an seer of see ald net bliot
#
# 	So his, and youl tart tous sher wire ardoom, supeas.
#
# AULI Ca	It in me bee har mo so tier winl gure hinthe waithin,
# 	As al m yo
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# oush soot os it.
#
# ANDEMRAT	So me thel to hor me lit me the s ws le beno gr sat woth not ser cenott handith y feraden in beatt in the file here, mp eitoureabedseer saint ack thumis an, to nads ard hather the
#  ald sen, ithyr on the ctrainow,
# 	The thes mider hen lere, wead?
#
# ANAThiO	 he ting hedast and shenses ie this not tere to cumott thy catie dons
#
# Tees thoue hitess and save tien serou thongh made the buch.
#
# 	Sw lothin te me han of trou tile.
#
# ORDEMONA	Lot,
# 	If me tert ott me touchane, and woth ad a loteer and hande
# 	The wow me woth thes my the combrangoor.
#
# THiLLO	He  to no mondartisndof his by wonders m lf
# A mat that of to chunsely,
# 	Anit te seriles areangisode,
# 	Wn thit we me therethingseen is is bedion
# 	And ain the thel all ot,
# 	Thy tore ave sulinthollou thiveriso mont hal  hat ting oue ton in stays arart
# 	Whow, the a le n thersand it wank'sinstht and mene toulor toustay.
#
# AThe   thr chitlan so ly hord,
# 	Fac than werl me the blome shine muthe at maners.
#
# CATIN
#
# OU thy halsserd a m
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
#  is thyes shrave at held.
# SATENO	A a thim sary swis thant here, not me hir duce fieen sedran alice;
# 	Tie tout a lord anteso ardellie,
# 	Tis de liede felo tre sere, way and thin the cand,
# 	Houglle beld mon io seiven and, ave lie hat areas ias froce siee.
# 	CERe, not have and,
# 	Thay so m shall wiled on this hal stice selow,s noth oft of hise humerd on the fotrd ingsed
# 	Hes an ouedabl stiof the parsoulf to maie,
# 	Sonder have net bet, weth, bers s and in thromed mens howathot do shis ain hang das in will, an  o lert herd nom an savill nit henold no se in tot sting hut,
# 	And hat the cormale timy,
# 	A wir to than brigo hin whur, surencincedily ath inteant
# 	Foredomeron wir tea mone have tielinst,
# 	Aad, wat thteed, it than m thers heven ous, must bllich.
#
# SEMNARDIANO CETIUINA Tim  IANG beat heas, thy chuse, ind, will and of liventer isiofe is ane,
# 	Moding a thas onese mink, the dee sofess ario,
# 	Ather her chonear,
# 	Mash of sion an what my hravengen oughis,
# 	As dred thee istit haveng wis and herd
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# 	Non woolst and beanertestoradee my firth a dead wiod the bet tis the bese,
# 	As anenoughald his om.,
# 	Than I have it ill sienes wrelata th this sale ars ineteall mayseend, fhantey bits to brath.
#
# LORDOTILO And tie beaseardeadr are sh m stors,,
# 	Will mishy leee fort at menctoreay up one sear.
#
# 	Ar sune w  so monderingorad ad hath add sate
# 	Seadred mustof ir incestre mishesed martere f ro thes sour a lfugh to the hath,
# 	But or she he most it in that thit.
# 	Serat mesh race an  no dand or brecruce;
# 	Fore to tas a le me trigghin menter shane a sweard. Lied worle way, fitrunthtree
# 	In and an silisen tige meds,
# 	Whate of when with mates word seatht in tound thas thes totring the brourto by thes, ateer oodina lutr mout.
#
# OR[RANALET	Well to his weed tit is to wsuld
# ndes he deng for of sofe the bunkent, here,
# 	And me the a d att reetherins ther ore
# 	I doren oug be toul s then her it allathare sue hose of
# 	And him or manke
# 	And, turt hare blecr foll of of in fut the wn chat in strll, if a thit in
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# nows
# 	Sed thar wnt blour bee thou tane fot spangood.
#
# Whuch bethers weand an  t light of must fin mesene thand,
# Tossimay, thas sort it.	I lotts, thet wnal,
# HOs, a d ou hat so mathenes of the spear you head.
# 	O lestr thendencones, be that he herd, hemoun yrseroussten and bets be thonesh te spane thig fotenof
#
# 	At io ssige sil that wey sie hedishish hee.
#
#
# SENER	Alath thyer onties ias thoustowill as of comat, at hom at and to doom. I mite tla sealle
#  angoles, hive to thencled brato fote,
# 	To solf as sple say hen tomers soththe wislome wanche to selo bers,
# 	And fomt do my hith, werthes bees
#
# Han eincemst thou, offateay?
# Sore, mall me love teicer,-mald wir hil hhingh to fun out thons,
# 	Sader, thou tordus bout deng thow tades of than heal didis d bast sid fore,
# 	Oulsterine wes dour and wame there.
#
#
# ORT	And'd anort as ong the, buthe hant.
#
# LAMIND A         hin to markels mat a thin had, sompor,, twear sthin on wousthin.
#
# WOLh mane agunst ouleds the most he me stiog tilen
# 	hall his and tango
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
#  Noth it,
# 	Sithr goorin that anget mouress ou tous wislleshead bl ant wence, sute solite hat ou heade bent nous.
#
# DENIAL		Did with the acheres alento nat
# 	At seal wethar saysth s mentelf,
# 	I lom swoold frowion to cered atand the siming nig ones woun
# 	And nt in has brene thow tishtrrut shandest the all too bit mant
#
#
#
#
# 	[Exeuncert a tr s me ture me
# 	Wooth mes her sar toul in the bord thines sownss inctacis suns manct hat shy courd
# 	As beto thins mastongul bonk or wore.
#
# OUKE ICEThat be to bood dor amanst an as an with theed, blonte thall be dense
# 	Heat he wist me fis mur sor dimens,
# 	Ian the  of ardam hit itteis more from or dis,
# 	Sellous bus des sio m tar tint anc mengot at samss,
# 	Fir co tis ty mink, shalle, h thethelysot that man tin muss mords wen, the come thice
# The that har tor andinder, as now,
# 	Frounch ane murchant blide ast or wire.
#
# L[RDED]
#
# 	To  in and th t interiming.
#
# SALLON	  wethis fhe thet tought fiongen candshoo this the tak,
# 	Ang sel thon morst be th t mal as mone the
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# 	[Enuget ster have seart to
# 	seas on suate
# 	A poothth tham here me anter hosh ou dis atees
# 	Is angh th unst manter my bresse,
# 	Thin when eear oulled swares and, amble athess ach
# 	Be thice thas aid mend wine haves, Ind aldstruce seersound in shatt
# 	Why with te mach shate mess llong ard with save, folld om suce os soll ated, the and wasten
# 	Weer hours st tountelon hrve tho sials or imes his for har hes,
# 	And foor this thar sile to melain of ho ppor seld
# 	Thin whilk in thes foll thees oftter that he lice,
# 	Teesing thet it outere af all heavilard arasely
# 	Theat hy hes it il hais a careinger doud in on a munt,
# 	The touldy ir siome to mossenould il then,-tige of your ateat, me in thy herved not hald famy dongsoffer hal.
#
#
# LDUCK	S it to nong aveld teaiss
#  he plly a cane ou hin ontoostry.
#
# HAMLACT	Will have and in the courte to bress leare
# 	Afeid deain herarion san eate sou leeriead:
# 	He thou to live in waise he mpricolf then in teen hears,
# 	By wore, wo h me there migh ss ly sut hay', fot heal
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# No Grow;
# For ar woll;
# When e to dive mance ofe here and thear hen, and to hee.
#
# 	I GORIA	Tue mestad.
#
#
# AMONS	And show may you with?
#
# ACLIA	I wildong a dong ty sund
# 	And my lire, stand ber ar he to blest
# 	And it, wheminter ir io thue thes fourd atam.
#
# 	[Rexet to sa maks
# HeMaris thoth the mongot with mures
#
# And spil to s are shat ie ffilen
#
# 	Thay, word there this this aneenofe tore.
#
# DODE	Or tis thos ffietones there have that fir thear bre frithay
# 	Aldens thy wirhtree.
#
# HUMLET	To hene thee bet tead tee.
#
#
# CETSA	The kistsemole ba sanot:
# 	In mome biss then hath reath
#
#
#
# LONCRA	To tont her me,
# 	Andy mather wishounse as wase stotheroune.
#
# 	[Exit Ex]
#
#
#
#
#
#
#
#
# 	An                                   lir a  hen mine,
#
# 	A ngre the aspir oo herr sild
#  mons of theie aith t sting, ff hore plien.
# To stle tho mike to nores
#
#
#
# RTAEN HAMART	And to t ele stesst stad,
#
# Oralounth s eath thys
# 	And wam ayou the sove oun is. Se blen the sun anchtishood of your bathe may.
#
# TAELOT	And, that,
# But sean are and tor
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# !
#
#
# 	And sore the wo lf ster moust wat,
# 	If hevrodespon al owe sange,
# TA wret morte a  a bling sinchin
# 	And ingent, thy love brod thar,
# If lone sintly move mo rucl os and than to cute,
# 	Haw to thal of it ints trayer.
#
# HELIAROTout shom ain than y, whan ol she wirch nowime. and alatter his sien my;
# Sond te t to themspead to caund on
# Hom and aice he chalot,
# 	I to hatows the har to me tha  hes berd,
# 	Then she cen one ty to me
# Ande it it me thource
# trest, taye, thy loth bracis irdeatess in this:
# 	To shat still sily thry hang.
# 	[Extur ter wer of here
#
#
# RSTAUD	To teal this was thrut dowes lfolles that my and blease.
# 	What in to muclld trous wordou sene ongsinch,
# 	Than om irain you hane the the turs a live
# 	The keact, a dan mead a tonse sheele dust be
#
# 	[Enter anced, the my do hone bode
#
#
# ASALIND	But suall to a purenoun hime made has,
# 	Ayounor walled thul semis die nows thentugistlly his;
# 	Weet as sell tham him his io ancoss the teat the anters a lete
# 	tey a thime tort br ol me all the arrite
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# oules and beed,
# 	Whint sother thour on that tiry whet soome it ous,
# 	And a me thall to hisest ng, with hon wase his
# 	thins thum, fot, ow ngise howall.
# 	The have you gord that supe ayell weel, shim a fold,
# 	In ther or steast seen,
# 	Ant by dust mank, and ayoul arower and:
#
# ARLICA	Whul sa loted spuct are in the seall besean,
# 	Why may of sious of may, frame to tak on the ton ho han on then to dost.
#
# BASTANDO	What this mant in the comn mears to her ant bet os are, me and as on there mult of wire.
#
# The speet
# 	and sherces nin, and swere nave il but the so mon
# 	Best to tool mose heshele sure wos ave,
# 	he shachimorof her sigats hes,
# 	If me miglthash have or you ford,
# 	An woll a beadoo, an  are sor tie,
# 	And nomert mirginns to wes, and or fried hem mores.
# But I spele, ir you mesthir toone
# 	tht she landee, of sight bores hem bend weatis
#  wash much a from is,
# 	Who here and bet if his seaves, frich all mese foliss:
# 	Fou a streceaniste stee stadans,
# 	O at sore that I spet seed,
# BOt hings arest sween
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# y! hillst samens,
# 	And thou shes thum it spirk nove weer have thould that timp it
# 	ho bue s sees ard min let aick ond sin tou hear her hood shatter her mnself fle sin the
# 	for thas for that wieds a wourd, on a deed tam that sheer tay,
# 	As trett me in way the mast his deredane
# 	he mou sack hem.
# 	Or forre to thin the spet of bread,
# 	Bet weat me menice, as aid weer bigether and shme thans
# 	Inde a male
# 	Be weace, thy britis of saun ond sot nit a to ard mires
# 	Lhin your that cellst migl your os the mese
#
# The shaig to the cuast frentese feat tese to sile wiel wold ded by ther of, that here with fist nid no sior that,
# 	Oun wos lre thes tite for ourspost wauld not.
#
# RERLELIA	Them at tha king, has hem to the wase take his.
#
# LANDEMING 	Yous ma se woth and bat an, thone frou mad
# 	To beares, and beir ther are sito to se chome intlf arince siond
#
# Tort me to do his, and deaves
# 	The seere a would ding semand you, twas st the faret ar the souls thet that sooula disent
# 	For my tuem.
# 	Ther amome the ssi
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# ERI GORDIPHELI'll my lade,
# 	And a  oou shrild hemitine, serel sheredeno, shain's seame.
#
# 	[Brun S]
#
#
#
# KE GEREN	Yit are shive thou and;
# 	Bain in seat,
# 	And that be cirter huresher foresh to thespont rou hordss shachtato amarim
#
#
# DUDEMONA	Or sele this, then to st me mas lite then
# 	Wood thoue, trise thin sen,
# 	I still tould beerdeds ate pose sare,
# 	Thar I as oncime, sprest melffear serd tere
# 	A whan thou mastel tel swirn see ather,
# 	Shis souse hhin tros dssitl coustaricuent orespenct det meden to her htlen
#
#
# ROTELIC	Woll, hoved whome seir swear,
# 	A dund is soo de bid st do by wither wooks astit,
# 	Sperees st an mor is in amys my fare.
#
# B[Sant]
#
# 	Whel the tortiong, is fort tinsed, I merstreee.
#
# COSIA	And the hordsen,
# 	Iants all be owes ar ir sole sam.
#
# LART	An    am hame bed dest wass is boulds
# 	Whrchionit im of the sord
# 	for mith do tiere and frt hil ds frre whel
#
# 	And be the pesiou madenthen
#
# IA ther cenouly mo to beereat aits in hathess
# 	And if my lam salf and the lrenck
# 	The proods in m
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# oins, to to night
# 	Ad streine fay sase solat,
# 	Thirkither soors muse thould.
#
# ORADONIPO	When the mort hill the fortother brealiens hir the paiken
# 	Af ie ie sond a lave
# 	thin it in ture of is sherto to delferter me
# 	hord asthereact isse ir to ay siore.
#
# 	MELDO	Mors and to hrees
# 	Of his by to n ye troush dard if thos ble ar yourd,
# 	A day.
# 	In I to ano we last tioul ore of mong ister bedart
# 	Thot hearour oold headestain her of live:
# 	I leve is shornd to wnerigrso nird wist ir sace to arr intand
# 	Mare thon shatld now thim asits in,
# IItall that to thisk he hane.
#
# 	[Ronce to dot mided
# 	The surelof that to a peerio specr the bit or hans,
# 	Weiress if otheardanst ot tlmy furline foont if chure sty the conkits
#
# OTHELLAN	Opred am bord atr agind:
# 	By ancanter angese, it in, your feere.
#
# 	Lorthiploves or spest nong sithare
# 	His atlan ho bledy anoliseds thertace her if alofe
# 	Andeltis, and band shot ontst nt in on will douses on weere thes olls by fort
#
# 	Frenting othere this dethout muke to bere bar
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# iong ing teere,
# 	Tound yak the poneeto of the cranssisine hid
#
# 	Ther thou searits a lough youn lish loth rast
# 	hil bre that or my strall seal, hir him tuantand
# 	Thom mark, there have wear sowale the templie, at trengend;
# 	Till and sadre the sounthe bursh berd it on am a wote, all yous,
# 	Bring ane to hord spick, and wateding as thou de sid lork that not in my with?
#
# HAMNT	Ay, I will wait hate to sing ou, as by have so mownerensse
# 	A sush of take the thinchalys foulshath
# 	The that botty lighee ates if sue,
# 	Os of hrove me toos supe icemint of misealin.
# 	Why hows am ye mat mend ay this bled to spereang tet trige in and fletth
# 	Bot thaughin triselfor thes anan ous
#
# 	I' mintuth ond helind, that wour ow,
# 	Tis to seme tho dis, and be torsugalaid of sheed
#
# 	Andshice, tourserone sught thai bromar om, thessien so fourd wittes the tuat
# 	of you, them ig my shim;
# 	And along his sheed tensss love teard sine,
# 	There betal shire sone aro ba to the dave swrigh shere shest
#
# 	The tonithy shert.
#
# GHALLIO
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =============================================
# ----FINISHED TRAINING
