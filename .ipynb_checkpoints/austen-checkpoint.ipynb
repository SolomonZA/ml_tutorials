# %%
import tensorflow as tf
from tensorflow.contrib import layers
from tensorflow.contrib import rnn
import os
import time
import math
import numpy as np
import my_txtutils as txt
import sys

tf.set_random_seed(0)
tf.reset_default_graph()

SEQLEN = 30
BATCHSIZE = 20
ALPHABETSIZE = txt.ALPHASIZE # 98 characters in vocab being used
INTERNALSIZE = 128
NLAYERS = 1

keep_prob = 0.8

# %%
# Load Shakespeare Data 

doydir = "doyle/*.txt"

codetext, valitext, bookranges = txt.read_data_files(doydir, validation=True)

# My_txtuils.py

    # uses glob for pathnames
    # convert_from_alphabet() - convert to ASCII values
# Out:
# Loading file austen/emma.txt
# Loading file austen/mansfield.txt
# Loading file austen/pride.txt
# Loading file austen/sense.txt

# %%
# Some statistics

epoch_size = len(codetext) // BATCHSIZE * SEQLEN

txt.print_data_stats(len(codetext), len(valitext), epoch_size)
# Out:
# Training text size is 3.13MB with 0.00KB set aside for validation. There will be 4925040 batches per epoch

# %%
# Placeholders

    # URL: https://learningtensorflow.com/lesson4/
    
"""Placeholder: a variable that we will assign data to at a later date. 
It allows us to create our operations and build our computation
graph, without needing the data. 

In TensorFlow terminology, we then feed data into the graph
through these placeholders."""

# Define placeholders 

keep_prob_placeholder = tf.placeholder(tf.float32, name = 'keep_prob') # dropout param
batchsize = tf.placeholder(tf.int32, name = 'batchsize')

# inputs 

X = tf.placeholder(tf.uint8, [None, None], name = 'X')
Xo = tf.one_hot(X, ALPHABETSIZE, 1.0, 0.0)

# expected outputs = same sequence shifted by 1 since we are trying
# to predict next character

Y_ = tf.placeholder(tf.uint8, [None, None], name = 'Y_')
Yo_ = tf.one_hot(Y_, ALPHABETSIZE, 1.0, 0.0)

# Input state

Hin = tf.placeholder(tf.float32, [None, INTERNALSIZE*NLAYERS], name = 'Hin')

# %%
# using NLAYERS of GRU cells, unrolled SEQLEN=30 times
# dynamic_rnn infers SEQLEN from the size of the inputs Xo

cells = [rnn.GRUCell(INTERNALSIZE) for _ in range(NLAYERS)]

# "naive dropout" implementaiton
dropcells = [rnn.DropoutWrapper(cell, input_keep_prob=keep_prob_placeholder) for cell in cells]

multicell = rnn.MultiRNNCell(dropcells, state_is_tuple=False) 

multicell = rnn.DropoutWrapper(multicell,
                               output_keep_prob = keep_prob_placeholder)
                                #dropout for the softmax layer

Yr, H = tf.nn.dynamic_rnn(multicell, Xo, dtype=tf.float32, initial_state = Hin)

# %%
# Softmax layer implementation
# Flatten the first two dimension of the output
    # [BATCHSIZE, SEQLEN, ALPHABETSIZE] => [ BATCHSIZE*SEQLEN, ALPHASIZE]
# then apply softmax laye.
    # Weights and biases are shared across unrolled time steps
    
W = tf.Variable(tf.random_normal([INTERNALSIZE, ALPHABETSIZE]))
B = tf.Variable(tf.random_normal([ALPHABETSIZE]))

Yflat = tf.reshape(Yr, [-1, INTERNALSIZE]) # [BATCHSIZE*SEQLEN, INTERNALSIZE]
Ylogits = tf.matmul(Yflat, W) + B # [BATCHSIZE*SEQLEN, ALPHASIZE]

Yflat = tf.reshape(Yo_, [-1, ALPHABETSIZE])

loss = tf.nn.softmax_cross_entropy_with_logits(logits = Ylogits, labels = Yflat)
loss = tf.reshape(loss, [batchsize, -1])

Yo = tf.nn.softmax(Ylogits, name = 'Yo')
Y = tf.argmax(Yo, 1)
Y = tf.reshape(Y, [batchsize, -1], name = "Y")

train_step = tf.train.AdamOptimizer(0.001).minimize(loss)

# %%
# Stats for display

seqloss = tf.reduce_mean(loss,1)
batchloss = tf.reduce_mean(seqloss)
accuracy = tf.reduce_mean(tf.cast(tf.equal(Y_, tf.cast(Y, tf.uint8)), tf.float32))

# Proress bar

DISPLAY_FREQ = 50
_50_BATCHES = DISPLAY_FREQ * BATCHSIZE * SEQLEN

progress = txt.Progress(DISPLAY_FREQ, size = 111+2,
                         msg = "Training on next" + str(DISPLAY_FREQ) +"batches")

# %%
# init

istate = np.zeros([BATCHSIZE, INTERNALSIZE * NLAYERS])

init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)
step = 0

# %%
# training loop

for x, y_, epoch in txt.rnn_minibatch_sequencer(codetext, BATCHSIZE,
                                               SEQLEN, nb_epochs =2):
    
    # train on one minibatch
    
    feed_dict = {X: x, Y_: y_, Hin: istate, keep_prob_placeholder: keep_prob, batchsize: BATCHSIZE}

    _, y, ostate = sess.run([train_step, Y, H], feed_dict=feed_dict)
    
    # display a short text generated with current weights and biases
    
    if step // 3 % _50_BATCHES == 0:
        print
        print "Generating some random text..."
        
        ry = np.array([[txt.convert_from_alphabet(ord("K"))]])
        rh = np.zeros([1, INTERNALSIZE*NLAYERS])
        
        for k in range(1000):
            ryo, rh = sess.run([Yo, H], feed_dict = {X: ry,
                                                     keep_prob_placeholder: 1.0,
                                                    Hin: rh, batchsize: 1})
            
            rc = txt.sample_from_probabilities(ryo, topn=10 if epoch <= 1 else 2)
            
            sys.stdout.write(chr(txt.convert_to_alphabet(rc)))
            
            ry = np.array([[rc]])
            
        print
        print "FINISHED GENERATING RANDOM TEXT"
        print
        
    # display progress bar
    progress.step(reset = step % _50_BATCHES == 0)
    
    # loop state around
    istate = ostate
    step += BATCHSIZE * SEQLEN
    
print 
print "----FINISHED TRAINING"
# Out:
# Generating some random text...
# ~,H|~MII)b#9~D|#O#~|#D~D,MDI|b#b9#bbb9M9Ib~x9xxbHx#xM|#xb~xHOH|HDxv~=O9~,9##9ObMM~OMb|#vOM9b~|#DIDv==#MD|DMD~IDM~Ob###~b#D~MO|=D,~#,~|=#|#~~|#~bII&#O~DIxx#~|#Mx]bx9x~#b~bH9Ix#|~=~~GG|G#IMI2D~D|,99#MD|DxM9|x~x#~~Ox#Mxx#~OOvH|~II~~IDI#~|D99b#|~M~9|=99~M99OMO|xx~xx~~(OH#|I~=|#D9x~|#99xO9#xxM#|xObxO]9h99O5|#OMI9xIIx#|I9#OII9bIIbWM~#IxIx|DI|~9I~xM~O#|M|v~I#v,#H~=9#~9ID|IxIxOx~=9O#O|9~9~|~~|D#O##99M
# ong har wouch mace bo but ia in that tere inty, may t im of hid se to bulf cundounter, thes sie sume that, them coof ithire as of at whet har have tha kedere teing, whas ownshord to as hen and wht ar and to my suaco himpance. ame thould be my
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# D|rgattane
# and
#
# That abait munct her
# ithers. I sther have tiellery, a suppasion at his
# antertofrsuensting at sist aish, at as moutinitiou his wathout
# anty whis saspabess thement
# ad int are the has of io shat sute bo nnttof she hit anl ittint.
#
#  hed hich wound seen ad
# herstine
# ther ter here, and sat in costha in ward hid dou dishroridectelituld same thatser. I astect on attar atlonn athersertthid they was ear at sat elotill,
# interses with, and suse form that ans
# of to tome toll be itenot ilang
# her
# fies, by
# sorm an would ha por by his cimuss oncy atee ssin sisuadens fere to a more ia nnt, as
# coneast in ser it whild ow of rectingll. I sushechou wough m redinnd ting en tanceread showe hempreratieg.
#
# The hourt, has har and speith a tir entownor.
# hever the rort, Ithapritted
# whal  ho mare a ation anteat of Mr. Touch wnothre same of
# mace, sheng is his assirage.
# Whout
#
# Ye the will, what hemo trat the him bess on titabs wassed or my tone ma ithends terts
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# siven there
# ande of the erer de thing, inteivir ot hem, an a that in were to birge wish ng thet reed did of it sur ead yo  sad bor thown whatltat midhe hact tuallanit the sas being to had sale to carmere ineand to mers noteme
# in wering of hine its much is in herstaid,, be his said well, to ersuried the would abant, on serast be al  it aladito of tut wholy ther the crond.
#
#  wom whin siofiof thy o the woule ar hale not her oftin ding at shat ther, and it is tie toort meto ne tham, be coored otles, her war esod adastand tit thy rrs sonce, to hive to hed her on hore spels of
# capain wnsest,"
#
# It is, astatim ge and aprased at ying notther insssulf chen cond her, with mowe the milt do had disulfet thin, ton cereld no belly. Brt with a might taner mon, and hove ind, shade
# how ant anste dingris caught had dilid atier sof erd andethe, bode th m mond aretery her mordinge on will the aintl wist, in the civesaitingremur this cillind therst ice magine in.
#
# "Batrenow dowe enougthat im
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# ingste fer she inly andectlidind. What have arto in al ous wave hed of theritlosen thopeste her freed im, as anairin th to tore hal she torid ht hap as no aly anged bre fur too he here then sers. He sie whrs ment sinceel om they all ot tal him sor her atooring, I ad it irtes intallystintito exesiro siting mend as in whol oo the ratel the wasty to merea in thance tre or batite inere ta bo witl tat yel for o nit rughing mestlatle ald ther as ofly; and andigantir morthise,ss
# could wat in ortor amerame. The whis hourh and saste se cincerin yore aid amate tane;
# not wf could his ane
# airayiods.
#
# THey ort eloubleds abthrage thar if stem surs to be the cosser, tot meane was the issowerougho wht to be athers. Themsesaydise the
# caned on then ish is to hasmoly was the estily wotll ablly. Westorsses wime to sued on a that
# im may sann the, suecliot, as of in shalided we him alltse me the ate now thatel is not men hortan oule mut orst burenies ineeatiento wosted. He are atastle. a tee every h
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================

# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# tntith tre ale acclesso and. Mrm an trans ond of to itty. Abor ald same how spast do moution ta eligide to her hon, ated, with or
# omareat of a mesting
# foomurn ald mich sarniegld her sasme to siet it, atenesh ates, add wet intole alf
# al as tras arits a limt to and ongam.
# ar timpore
# to nhis his ont ane as of the was and wive way be whited eeas te
# to the wele. I dipalle shoptent her for his well not te wothan soor and in aid forther
# washer home wish
# he hard, he was whit oushing ale asteare waid to be as of it tainss olf the shathould herss a chuct shim with hearily; in the coupe, tret lore; and was al with prof retions themplation for misters, whin shad an and werleshited this is mighted sister her theractinactidagitndistars, on her hissallioghe to dare the plenery for tho kinwelinse be nor whe her fort tho was an that in, and a surse chised oo dase, or thes aideas to har a of stous, and hererent andeanto samare soor
# t worke, but
# and her wo the of hir forme the teer, shal the
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# nveghe to hard thayshive wand har eeserit when befort site, him shas of a compat al should
# bein most, that hat be that allene t me ham tain tark, in woness wo know, wo mak ng that, an athis out being which sellean form tas nongrong on
# and main.
# thim she for ams spoit so welter
#  he fannis ir. Ill wo kname
# leatiou to meat than h would me neat shile tan the soolen sais, and she of touns,--of as manter the was thet to have beensing so being all if tiong wheth with harr of whatesht of star tuch, and that soments but have if the comste but be sorde home of the asmupt. Mr. Duch a sundien wo shaping have s ore, him the was to whupe im his
# anoursss ad or shas spteare. Hat io dould
# een wisher to are torsity, and whach of
# r ain she, orther him, to shat being in licking---they a l om  she can, in orders.
#
# I waie  ho dould that ane, as to
# wher stion an the pathoract, sinh age thes.   are do you mote hame suppea isayo  affistsing thin dho glind ther aritale for mad ney
# this an
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# nevorl, in it to his him a sating was been in ortueestary thing is we chame to her of hmusirn is she did now her my nownded
# how." I toolers tee to certly, ond, in the part forly of but.
# trind to her
# prondacl your of every tol  ald not musicene was teom, be when atress couse,
# her weat they a wese fout the
# pos thert
# cart that bely. The havill beel at art is most fome had
# could net a renother sure
# sore might honsert br nuce ous, for
# may the was were st appaiss to to hil with had t s the thergedeat and, and thich mary,
#
# the linder hers.  I way
# she feed, ho hat was one cepto tims, a doons the prat ess, and was now it the to tem
# a perter
# stmo toly there from. It lade he was
# asare and is in e all to the but been be the walkner an her an hadellyero dort,
# eres could and the could and ancine, to
# hrrsed ancoss ad to sele ferestrering stor are hed herelis tho mes to be song to domat al as teand was but in ter sitied. But see was with as weal
# assent hos cortuted, and it in as in
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================

# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# th wear her and noreful had been cepting it spat, he his orced.  he has no
# suth to douade sofage if moment,
# in with her and hartless felt of the to well in.--Sor on her
# will, said I smill of Mr. Forris mother's party to say bus sht she could be should be and to his beise, on shapion of the pare.
#
#  I  owh, though I
# hapannes on the citsore for the swame the wousd sate ansises; and fures at ance shat will your, is was time by we chuse that a taskiog, in favours, had soe deting at whil the mrate, for all ate to by it and, in things was bas abselt tain suapered.  They tume seeredsan fom. Mory arows on ortstable to may thomis to wist as that she phased of the
# came a sint to be ferticied worl, teat the dere,
# ip a relyed talk; now in mind wo seed bela, amans sighter was all at thair that he maken that is be a filly culle cercans your her ortalother s on the tricchands to do be mone me head. Miss Bennea what her shapse in well--by ter st id the the dinged--and as andallage much mo
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# itt, their opea trowal of
# treid.
#
# "I stive it on your
# will nither to mind at athan whem without. Into me appeated to must of more speake, he
# condersion
# with, which it,
# sisher wosed it tooblibtly.   heasters over what sersitation in the wethoum to be that you well was no sectite eft tien of the reating as it issorase tromantance
# accapeer
# o list, affore moretased though fair bliget, with thes taunce was a signet sayoulance, than a soon but by one assalain of countrine intundes mfthir one tirget, and their than
# and
# oresing. The
# was were was exore.-She their that her perpected ho tolaccouding to there wife, and sucuirared been; in had not expuity whith til the be sure in their bettem to as has town will the rong more as she it whimisg to a would
# foltitumber friely by ste telies in had shich
# her instlontaginne, trough, thationase
# when she doppy it be amabre, an to ach then soor the fims. The mading atters were with tert the streach, a dunten a art tamannet, in thet site
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# nt hanced intinced of tounder how vary herselved were her
# precence of. Toughthtonat, and which
# perhed beere as or absecting of oling shishill and was has no been
# at
# offecterattess on timparss to be trangious
# from could in acquianted.
#
# Well.  Whon donning
# outing or thing answald. This the have to a contering. And in indarione and him as sore if in a
# complasiey.
# Hew that half to be formire, and muth a toweriss of a mare eness went do a sothing his ware.
#
# His moneners soon
# condeal be tisting on your bettioled.
#
#
# It is all ment thence muat her fistet of it, the
# coonctes of the comperting mere insureding to ast and high his as nother of,
#
# Yes, and move seen colldsely
# is to her other, im of the began in
# the hear of can afort that ho opinion
#
#
# I wisting.
#
# I am the te leas, bur oney ard toly thethead on thing wole be to shit erething to such it
# poseatime at thong as by
# coused on the distiosaliobs. The rights agains, and sure hos howirg in, bef
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# ry
# had have say ic es insicer, the rsprescacton at him eisgared. Str thancimasate a fortshoomy or weem. I was by in aingetation,
# of in what is attended it a d in his wotton.
#
# I soou let ous to be hir any the hau not en every that hather was bit to sire, and it
# and ady fined bin at has, however," send you wret enting that yourse, for a volading a comfort despendance to her teen mugh sualed in seess hor, of their must
# to be on carring to carive of to he repas you simily heare. There ir.
#
# The sespose itton of his cearatton. They
# ad al the heppisest over doow but walshoudenevess inds perits and on to his that ilon ard time theing this flencisudes to hen to ning thirgh,
#  It ma le hapines a stownting he winder t ous as was
# to be in
# thengsomethem the rount. Muss, sere thal, he havibutiove to be ofer ctrang folther sharal about the my an thank
# on in to be
# tound becouvice wnout, would be sinteen this it spould have to muct arriected, any one hirself shatinnom it ss posions at e
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# ntiof, he sesten it took it time, it that the make
# to eapes, and with yin will ser
# munt, fere the was ont the mamacong enow house of that a partuale a mace as at wonk the dutrectady have all any ansurated to be mysern. The aspossiculiaged a can of her ousting the
# whal  happised be at some, saic ingital
# in her. It in the come so be nerarding ot in seass, and
# and werine may own to selt and affore as. But I
# waild errop ine or the wanting for the deabld her or the sentered that is.
#
# Not sure her that in condediter of it a mastantin at men the wish say itails and hove or a prevenes, an him t and his fences of him
# porthing obe talked on his
# bettaines, ood of she fook through his andinand of she
# she callownor
# say what seen to consure anowr was ald tee chas best then has noured, fillted the mects wn hes in it. He for ant tann to the wink whing we gling anom her at sually it two deably age in thing an about that
# bowand time; in a recteratter opot hood of curserver
# born supar
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# ethtre it tas e to a mademettle teat he sconeding enlight. There.)
#
# I
# conser not so pant.
#
# A a subserting oftany all
# temeed in to a rett anstor the of
# santion bothore a full.
#
# Elton, the ligst who was so no ried with at ceind,-to hope you keem by house but, I openith; but as sure a drne and. See in wise it weat or think
# as
# one it so nature tf and
# impere the panned is neat owa derelite, and howns to been a the lincle hid tomest stre alabost which memint facted being being al
# a coomas of
# hould. Mr
# Wishwond.--Yes net, then the consuruilidatl the corrse thorg ter this ap indonsiborthe wiscomple than cerrardon forther?-"You dill some came for or, of is a ghan when there her found is an a poreice to, he reclise to be
# or offineditrought, thengs ag simele cance to be
# out excembets.
#
# Hosinf couse if in cheare agal, the, which the getlecill centioued a most.--Here the corsconsistincactes of
# berived to the tist comporain that cersuce of the pounite
# ofly.
# You m
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================
# Generating some random text...
# nhttratione twak he to mother be warentious in hrusting mirst when is to me touch shink othert before made the sand, in
# which stoubd even thome allou drew it of--hands see whin
# this happy hindect.
#
# I aitlong thensole to canner. Mr  than with it to dooniffersteptlise of miss of the subjecs. She could to his shiees mastistand her
# trooking on the said truat are it sand on the dilogreat to her other
# was that he sight halk. What is
# andien eroust forther betered that I sare what, s hartayly to desill ot trakenter bothim.   t enools and this to coice mishtal he thing thowndrr. Mr. Elton, and
# his eape, is his of the
# would be
# ser she had set london, that he happing but how it apposed to strite amess she wold be ows admetisted.
#
#
# Affection with the world.
#
# Bit, and some and fathlr;-and that
# and tall by afoum.
#    and them to hear though, as meerivable and in launeles.
#
#
#
# Madfair, af ering-two my do them, and he cound
# connot, as that woich with had food of a
# FINISHED GENERATING RANDOM TEXT
#
# ()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# =================================================================================================================()
# 0%                                         Training on next50batches                                         100%
# ===================================================================================================
# ----FINISHED TRAINING
